# %% [markdown]
# # EDA
# 1. General plots of demographics -> breakdown by republican and democrats?
# 2. Maybe some plots on which county switched from D -> R or R-> D
# 4. Get updated demographics for 2020?
#
# Classes needed for EDA? Unlikely
# Functions? Probably - plotting, choropleth plots with county data
# Function for calculating electoral college votes. pd.merge on state?
# One hot encoder to prep

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

from src import explorers

# For choropleth plots
from urllib.request import urlopen
import json

# %%
# Load data and put fips as string
pd.set_option("display.max_columns", 40)
data = pd.read_csv('data/cleaned_data.csv', dtype={'fips': str})
population_data = pd.read_csv('data/population.csv')

# Drop the extra column in dataframe
data.drop(columns='Unnamed: 0', inplace=True)
data.head()
# Out:
#      state   county  fips  white_pct  black_pct  hispanic_pct  nonwhite_pct  \
# 0  Alabama  Autauga  1001  75.683482  18.370906      2.572254     24.316518
# 1  Alabama  Baldwin  1003  83.178788   9.225603      4.366698     16.821212
# 2  Alabama  Barbour  1005  45.885624  47.888329      4.309762     54.114376
# 3  Alabama     Bibb  1007  74.765196  21.212121      2.223994     25.234804
# 4  Alabama   Blount  1009  87.657701   1.557951      8.727298     12.342299
#
#    foreignborn_pct  female_pct  age29andunder_pct  age65andolder_pct  \
# 0         1.838362   51.176225          40.037058          13.978456
# 1         3.269510   51.194928          35.474412          18.714851
# 2         2.859397   46.498084          37.664387          16.528895
# 3         1.351232   46.464646          37.329435          14.885699
# 4         4.271801   50.485235          37.240053          17.192916
#
#    median_hh_inc  clf_unemploy_pct  lesshs_pct  lesscollege_pct  \
# 0        53099.0          5.591657   12.417046        75.407229
# 1        51365.0          6.286843    9.972418        70.452889
# 2        33956.0         12.824738   26.235928        87.132213
# 3        39776.0          7.146827   19.301587        88.000000
# 4        46212.0          5.953833   19.968585        86.950243
#
#    lesshs_whites_pct  lesscollege_whites_pct  rural_pct  trump16_pct  \
# 0          10.002112               74.065601  42.002162    72.766588
# 1           7.842227               68.405607  42.279099    76.545712
# 2          19.579752               81.364746  67.789635    52.096666
# 3          15.020490               87.471774  68.352607    76.403220
# 4          16.643368               86.163610  89.951502    89.334844
#
#    clinton16_pct  otherpres16_pct  romney12_pct  obama12_pct  otherpres12_pct  \
# 0      23.769671         3.463741     72.618252    26.587832         0.793916
# 1      19.385601         4.068687     77.358269    21.589444         1.052286
# 2      46.527844         1.375490     48.223130    51.368494         0.408376
# 3      21.249575         2.347205     72.826603    26.152019         1.021378
# 4       8.425825         2.239331     86.465884    12.371907         1.162209
#
#    cvap_pct12  metro  rural  urban_metroadj  urban_not_metroadj
# 0   58.815434      1      0               0                   0
# 1   56.228504      1      0               0                   0
# 2   56.485890      0      0               1                   0
# 3   47.868107      1      0               0                   0
# 4   56.577893      1      0               0                   0

# %%
# Let's look at some state level statistics -> come back to this later
data_not_clean = pd.read_csv('data/election-context-2018.csv')
data_not_clean.groupby('state').agg(
    trump16 = pd.NamedAgg(column='trump16', aggfunc=sum),
    clinton16 = pd.NamedAgg(column='clinton16', aggfunc=sum),
    otherpres16 = pd.NamedAgg(column='otherpres16', aggfunc=sum),
    female_pct = pd.NamedAgg(column='female_pct', aggfunc=np.mean),
)
# Out:
#                       trump16  clinton16  otherpres16  female_pct
# state
# Alabama               1318250     729547        75570   51.274657
# Arizona               1252401    1161167       215188   49.552147
# Arkansas               684872     380494        64530   50.583493
# California            4483810    8753788       943997   49.313065
# Colorado              1202484    1338870       238866   48.473611
# Connecticut            673215     897572        74133   50.822568
# Delaware               185127     235603        22267   51.618145
# District of Columbia    12723     282830        15715   52.560739
# Florida               4617886    4504975       297178   48.700135
# Georgia               2089104    1877963       147644   50.396197
# Hawaii                 128847     266891        33199   49.988087
# Idaho                  409055     189765        91613   49.172417
# Illinois              2146015    3090729       321963   49.906492
# Indiana               1557286    1033126       144546   50.217236
# Iowa                   800983     653669       111379   50.155423
# Kansas                 671018     427005        86380   49.773449
# Kentucky              1202971     628854        92324   50.323202
# Louisiana             1178638     780154        70240   49.934359
# Maine                  334945     354718        54278   50.879262
# Maryland               943169    1677928       160349   50.927924
# Massachusetts         1090893    1995196       188466   51.332933
# Michigan              2279543    2268839       250902   49.581273
# Minnesota             1322951    1367716       254146   49.854513
# Mississippi            700714     485131        23512   51.061250
# Missouri              1594511    1071068       141802   50.145434
# Montana                279240     177709        40198   49.317504
# Nebraska               495961     284454        63772   49.986874
# Nevada                 512058     539260        74067   47.981455
# New Hampshire          345790     348526        49980   50.372408
# New Jersey            1601933    2148278       123835   51.047099
# New Mexico             319667     385234        93418   49.534792
# New York              2814589    4547562       345212   50.246189
# North Carolina        2362631    2189316       189617   50.903128
# North Dakota           216794      93758        33808   48.827066
# Ohio                  2841005    2394164       261318   50.302083
# Oklahoma               949136     420375        83481   49.745395
# Oregon                 782403    1002106       216827   50.035031
# Pennsylvania          2970733    2926441       218228   49.819039
# Rhode Island           180490     251888        31038   51.508604
# South Carolina        1155389     855373        92265   50.969022
# South Dakota           227721     117458        24914   49.467107
# Tennessee             1522925     870695       114407   50.460848
# Texas                 4685047    3877868       406311   49.160628
# Utah                   515231     310676       305523   49.071879
# Vermont                 95369     178573        41135   50.473680
# Virginia              1769443    1981473       233715   50.615785
# Washington            1221747    1742718       244749   49.978377
# West Virginia          489371     188794        34886   50.133873
# Wisconsin             1404440    1381823       189490   49.595907
# Wyoming                174419      55973        25457   48.952957

# %%
# First, which counties went most strongly for trump or clinton?
columns_of_interest = ['state', 'county', 'white_pct', 'nonwhite_pct', 
                       'trump16_pct', 'clinton16_pct', 'otherpres16_pct']
data[columns_of_interest].sort_values(by='white_pct', ascending=False)
# Out:
#               state     county   white_pct  nonwhite_pct  trump16_pct  \
# 1602        Montana  Petroleum  100.000000      0.000000    86.335404
# 1715       Nebraska    Wheeler   99.627329      0.372671    81.075269
# 3011  West Virginia    Webster   99.569161      0.430839    77.300201
# 2833       Virginia   Highland   99.551570      0.448430    68.871316
# 1017       Kentucky    Jackson   99.386090      0.613910    88.874750
# ...             ...        ...         ...           ...          ...
# 2745          Texas     Zavala    5.798299     94.201701    20.435807
# 2515          Texas     Brooks    5.334627     94.665373    23.613251
# 2731          Texas       Webb    3.482628     96.517372    22.751955
# 2653          Texas   Maverick    2.776702     97.223298    20.724168
# 2705          Texas      Starr    0.760221     99.239779    18.943782
#
#       clinton16_pct  otherpres16_pct
# 1602       9.316770         4.347826
# 1715      13.333333         5.591398
# 3011      18.670248         4.029550
# 2833      26.671459         4.457225
# 1017       8.762043         2.363207
# ...             ...              ...
# 2745      77.620730         1.943463
# 2515      74.614792         1.771957
# 2731      74.346718         2.901327
# 2653      76.516044         2.759788
# 2705      79.122658         1.933560
#
# [3111 rows x 7 columns]

# %%
# Let's look at some correlations in the data
plt.figure(figsize=(12,10))
sns.heatmap(data[data.columns[3:]].corr(), cmap='bwr', vmin=-1, vmax=1)
plt.title("Correlation Heatmap")
plt.savefig('images/corr_heatmap.png', bbox_inches='tight', dpi=350)

# %%
# Drop some of the redundant columns
columns_to_drop = ['nonwhite_pct', 'lesshs_whites_pct', 'lesscollege_whites_pct']
data.drop(columns=columns_to_drop, inplace=True)

# %%
# Redo heatmap
plt.figure(figsize=(12,10))
sns.heatmap(data[data.columns[3:]].corr(), cmap='bwr', vmin=-1, vmax=1)
plt.title("Correlation Heatmap")
plt.savefig('images/corr_heatmap2.png', bbox_inches='tight', dpi=350)
